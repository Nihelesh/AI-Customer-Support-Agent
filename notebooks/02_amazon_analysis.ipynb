# %%
import pandas as pd

df = pd.read_csv("../data/raw/twcs.csv")

# %%
df["in_response_to_tweet_id"] = pd.to_numeric(
    df["in_response_to_tweet_id"],
    errors="coerce"
).astype("Int64")

# %%
parent = dict(
    zip(
        df["tweet_id"],
        df["in_response_to_tweet_id"]
    )
)


def find_root(tweet_id):
    visited = set()

    while pd.notna(parent.get(tweet_id)):

        if tweet_id in visited:
            break

        visited.add(tweet_id)

        tweet_id = int(parent[tweet_id])

    return tweet_id


df["conversation_id"] = df["tweet_id"].map(find_root)

# %%
amazon_conversation_ids = df[
    df["author_id"] == "AmazonHelp"
]["conversation_id"].dropna().unique()


amazon_df = df[
    df["conversation_id"].isin(amazon_conversation_ids)
].copy()

# %%
print("Shape:")
print(amazon_df.shape)

print("\nNumber of unique conversations:")
print(amazon_df["conversation_id"].nunique())

print("\nInbound value counts:")
print(amazon_df["inbound"].value_counts())

print("\nTop 10 authors:")
print(amazon_df["author_id"].value_counts().head(10))
# Out:
# Shape:
# (374042, 8)
#
# Number of unique conversations:
# 82534
#
# Inbound value counts:
# inbound
# True     203598
# False    170444
# Name: count, dtype: int64
#
# Top 10 authors:
# author_id
# AmazonHelp    169840
# 169172           447
# UPSHelp          322
# 115850           243
# Tesco            172
# 326613           163
# 158494           119
# 469296           116
# 177530            99
# 270757            86
# Name: count, dtype: int64

# %%
other_outbound_authors = (
    amazon_df[
        (amazon_df["inbound"] == False) &
        (amazon_df["author_id"] != "AmazonHelp")
    ]["author_id"]
    .value_counts()
)

print("Number of other outbound authors:",
      other_outbound_authors.shape[0])

print(other_outbound_authors.head(30))
# Out:
# Number of other outbound authors: 25
# author_id
# UPSHelp           322
# Tesco             172
# XboxSupport        14
# hulu_support       11
# SpotifyCares       10
# JetBlue             9
# BofA_Help           8
# ChaseSupport        8
# AskeBay             7
# AppleSupport        6
# AskPayPal           6
# ArgosHelpers        5
# AskSeagate          5
# Morrisons           4
# DellCares           2
# idea_cares          2
# AskPlayStation      2
# MicrosoftHelps      2
# AskAmex             2
# AsurionCares        2
# Uber_Support        1
# Ask_Spectrum        1
# AskTarget           1
# AldiUK              1
# TMobileHelp         1
# Name: count, dtype: int64

# %%
# Find conversations where UPSHelp appears
ups_conversation_ids = amazon_df[
    amazon_df["author_id"] == "UPSHelp"
]["conversation_id"].unique()

print("Number of conversations involving UPSHelp:",
      len(ups_conversation_ids))
# Out:
# Number of conversations involving UPSHelp: 246

# %%
sample_ups_conversations = pd.Series(
    ups_conversation_ids
).sample(3, random_state=42)

for conversation_id in sample_ups_conversations:

    print("=" * 100)
    print(f"Conversation: {conversation_id}")
    print("=" * 100)

    conversation = amazon_df[
        amazon_df["conversation_id"] == conversation_id
    ].copy()

    conversation = conversation.sort_values("created_at")

    print(
        conversation[
            [
                "tweet_id",
                "created_at",
                "author_id",
                "inbound",
                "text"
            ]
        ].to_string(index=False)
    )

    print()
# Out:
# ====================================================================================================
# Conversation: 483724
# ====================================================================================================
#  tweet_id                     created_at  author_id  inbound                                                                                                                                                                                                                                                              text
#    483724 Fri Dec 01 14:49:13 +0000 2017     230075     True                                                                 @115817 @115821\n\nI have an order with two day delivery paid option placed on 27th Nov. Still items (tracking #1Z973Y6A0300840635) not delivered. Now I am leaving from town. Will miss my items
#    483722 Fri Dec 01 14:55:53 +0000 2017 AmazonHelp    False                                                                                                                     @230075 I'm sorry your items won't be arriving before you leave. We'd like to review your available options here: https://t.co/hApLpMlfHN ^RA
#    483726 Fri Dec 01 15:06:25 +0000 2017    UPSHelp    False                                   @230075 I do apologize as it appears that UPS did not receive this package until yesterday, this package is showing it is going to be delivered today. If you need further assistance please DM us. ^AC https://t.co/wKJHDXWGRQ
#    483723 Fri Dec 01 18:07:43 +0000 2017     230075     True                                                                      @AmazonHelp There's nothing I can do on the link. I need either to cancel the whole order without any charge to me or ship it to my Oman address refunding 2 day expedited delivery charges.
#    483725 Fri Dec 01 18:11:01 +0000 2017 AmazonHelp    False @230075 The link that RA provided should put you in direct contact with our customer service department. You can choose either phone or chat. In this way we can see if we can either cancel the shipment for you, or change the address. We're here to help! ^JD
#
# ====================================================================================================
# Conversation: 71834
# ====================================================================================================
#  tweet_id                     created_at  author_id  inbound                                                                                                                                                                                               text
#     71834 Thu Nov 30 10:13:01 +0000 2017     132119     True @115817 the Amazon package I'm waiting for is at the local delivery hub, ,supposed to be delivered today. Notified of a carrier delay, and delivery will be rescheduled. Whhaatis a carrier delay?
#     71833 Thu Nov 30 10:18:00 +0000 2017 AmazonHelp    False                                                              @132119 Carrier delays can be caused by different factors. Is there any further information on the carriers own website tracking? ^MI
#     71832 Thu Nov 30 10:20:11 +0000 2017     132119     True                                                                                                            @AmazonHelp UPS website says delayed due to unexpected circumstances. Not very helpful.
#     71831 Thu Nov 30 10:26:28 +0000 2017 AmazonHelp    False @132119 I'm sorry about the delay and lack of information. Usually these delays are resolved very quickly and your order could still reach today. Let us know if there are no further updates. ^MI
#     71835 Thu Nov 30 13:48:23 +0000 2017    UPSHelp    False                                                               @132119 Do you have a specific package we can assist you with? Please DM our team your tracking details. ^DS https://t.co/wKJHDXWGRQ
#
# ====================================================================================================
# Conversation: 2527671
# ====================================================================================================
#  tweet_id                     created_at  author_id  inbound                                                                                                                          text
#   2527671 Thu Nov 16 04:39:48 +0000 2017     719704     True             Hi guys. @115786 @115817 @115821 I bought my Xbox box one x this week and this how looks. https://t.co/MBZn9S8c0I
#   2527670 Thu Nov 16 04:43:56 +0000 2017 AmazonHelp    False                                                                               @719704 I responded to your direct message! ^LA
#   2527672 Thu Nov 16 06:07:01 +0000 2017    UPSHelp    False                                                                               @719704 Is the item damaged inside the box? ^AD
#   2529055 Thu Nov 16 06:12:27 +0000 2017     719704     True @UPSHelp Not, it is fine , looks good, but i  just turn it on. I always want a product in good condition, inside and outside.

# %%
amazon_df = amazon_df.copy()

# %%
amazon_df["created_at"] = pd.to_datetime(
    amazon_df["created_at"],
    utc=True
)
print(amazon_df["created_at"].dtype)
print(amazon_df["created_at"].head())
# Out:
# C:\Users\Nihelesh M U\AppData\Local\Temp\ipykernel_22432\1088289157.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   amazon_df["created_at"] = pd.to_datetime(
# datetime64[ns, UTC]
# 181   2017-11-22 09:23:01+00:00
# 182   2017-11-22 09:24:30+00:00
# 183   2017-11-22 09:30:36+00:00
# 184   2017-11-22 09:40:27+00:00
# 185   2017-11-22 09:44:04+00:00
# Name: created_at, dtype: datetime64[ns, UTC]

# %%
amazon_sorted = amazon_df.sort_values(
    ["conversation_id", "created_at"]
).copy()

conversation_id = 483724

conversation = amazon_sorted[
    amazon_sorted["conversation_id"] == conversation_id
]

print(
    conversation[
        [
            "conversation_id",
            "tweet_id",
            "created_at",
            "author_id",
            "inbound",
            "text"
        ]
    ].to_string(index=False)
)
# Out:
#  conversation_id  tweet_id                created_at  author_id  inbound                                                                                                                                                                                                                                                              text
#           483724    483724 2017-12-01 14:49:13+00:00     230075     True                                                                 @115817 @115821\n\nI have an order with two day delivery paid option placed on 27th Nov. Still items (tracking #1Z973Y6A0300840635) not delivered. Now I am leaving from town. Will miss my items
#           483724    483722 2017-12-01 14:55:53+00:00 AmazonHelp    False                                                                                                                     @230075 I'm sorry your items won't be arriving before you leave. We'd like to review your available options here: https://t.co/hApLpMlfHN ^RA
#           483724    483726 2017-12-01 15:06:25+00:00    UPSHelp    False                                   @230075 I do apologize as it appears that UPS did not receive this package until yesterday, this package is showing it is going to be delivered today. If you need further assistance please DM us. ^AC https://t.co/wKJHDXWGRQ
#           483724    483723 2017-12-01 18:07:43+00:00     230075     True                                                                      @AmazonHelp There's nothing I can do on the link. I need either to cancel the whole order without any charge to me or ship it to my Oman address refunding 2 day expedited delivery charges.
#           483724    483725 2017-12-01 18:11:01+00:00 AmazonHelp    False @230075 The link that RA provided should put you in direct contact with our customer service department. You can choose either phone or chat. In this way we can see if we can either cancel the shipment for you, or change the address. We're here to help! ^JD

# %%
amazon_sorted["turn_number"] = (
    amazon_sorted
    .groupby("conversation_id")
    .cumcount() + 1
)

conversation = amazon_sorted[
    amazon_sorted["conversation_id"] == 483724
]

print(
    conversation[
        [
            "conversation_id",
            "turn_number",
            "tweet_id",
            "created_at",
            "author_id",
            "inbound",
            "text"
        ]
    ].to_string(index=False)
)
# Out:
#  conversation_id  turn_number  tweet_id                created_at  author_id  inbound                                                                                                                                                                                                                                                              text
#           483724            1    483724 2017-12-01 14:49:13+00:00     230075     True                                                                 @115817 @115821\n\nI have an order with two day delivery paid option placed on 27th Nov. Still items (tracking #1Z973Y6A0300840635) not delivered. Now I am leaving from town. Will miss my items
#           483724            2    483722 2017-12-01 14:55:53+00:00 AmazonHelp    False                                                                                                                     @230075 I'm sorry your items won't be arriving before you leave. We'd like to review your available options here: https://t.co/hApLpMlfHN ^RA
#           483724            3    483726 2017-12-01 15:06:25+00:00    UPSHelp    False                                   @230075 I do apologize as it appears that UPS did not receive this package until yesterday, this package is showing it is going to be delivered today. If you need further assistance please DM us. ^AC https://t.co/wKJHDXWGRQ
#           483724            4    483723 2017-12-01 18:07:43+00:00     230075     True                                                                      @AmazonHelp There's nothing I can do on the link. I need either to cancel the whole order without any charge to me or ship it to my Oman address refunding 2 day expedited delivery charges.
#           483724            5    483725 2017-12-01 18:11:01+00:00 AmazonHelp    False @230075 The link that RA provided should put you in direct contact with our customer service department. You can choose either phone or chat. In this way we can see if we can either cancel the shipment for you, or change the address. We're here to help! ^JD

# %%
first_turns = (
    amazon_sorted
    .groupby("conversation_id")["turn_number"]
    .min()
)

print(first_turns.value_counts())
# Out:
# turn_number
# 1    82534
# Name: count, dtype: int64

# %%
url_count = amazon_sorted["text"].str.contains(
    r"http|https|t\.co",
    case=False,
    regex=True,
    na=False
).sum()

mention_count = amazon_sorted["text"].str.contains(
    r"@\w+",
    regex=True,
    na=False
).sum()

newline_count = amazon_sorted["text"].str.contains(
    r"\n",
    regex=True,
    na=False
).sum()

print("Tweets containing URLs:", url_count)
print("Tweets containing mentions:", mention_count)
print("Tweets containing newlines:", newline_count)

print("Missing text:", amazon_sorted["text"].isna().sum())

print(
    "Empty text:",
    (amazon_sorted["text"].str.strip() == "").sum()
)
# Out:
# Tweets containing URLs: 102691
# Tweets containing mentions: 362685
# Tweets containing newlines: 21632
# Missing text: 0
# Empty text: 0

# %%
mention_examples = amazon_sorted[
    amazon_sorted["text"].str.contains(
        r"@\w+",
        regex=True,
        na=False
    )
]["text"].head(20)

for text in mention_examples:
    print(text)
    print("-" * 100)
# Out:
# @115770 こんにちは、アマゾン公式です。Fire TV Stickが見れないというのは、どのような状況でしょうか。一般的なトラブルシューティングを記載したヘルプがございますので、ご参照ください。https://t.co/2pbG55qJ7h ET
# ----------------------------------------------------------------------------------------------------
# @AmazonHelp ありがとうございます。
# 今、電話で主人が対応していただいてます。
# ----------------------------------------------------------------------------------------------------
# @AmazonHelp 電話で対応してもらいましたが改良されませんでした。
# 保証期間も過ぎてるので買い直しになるんでしょうね。
# ----------------------------------------------------------------------------------------------------
# @115770 カスタマーサービスにてお問い合わせ済みとのことで、お手数をおかけいたしました。リプライいただきありがとうございました。ET
# ----------------------------------------------------------------------------------------------------
# @AmazonHelp こちらこそありがとうございました。
# ----------------------------------------------------------------------------------------------------
# @115770 恐れ入ります。至らない点も多々あるかとは存じますが、今後ともどうぞよろしくお願いします。ET
# ----------------------------------------------------------------------------------------------------
# @115792 ご不便をおかけしております。アプリをご利用でしょうか。強制停止&gt;端末の再起動にて改善する場合がございますので、お試しください。改善しない場合は、状況を確認しご案内させていただきますのでこちらからカスタマーサービスまでご連絡ください。https://t.co/NtNAX2Qh2u ET
# ----------------------------------------------------------------------------------------------------
# Way to drop the ball on customer service @115821 so pissed right now!
# ----------------------------------------------------------------------------------------------------
# @115820 I'm sorry we've let you down! Without providing any personal information, will you describe the issue? We'd love to help. ^TN
# ----------------------------------------------------------------------------------------------------
# @AmazonHelp 3 different people have given 3 different answers and I still don't have my order. Says delivered Saturday, was not, I was home all day
# ----------------------------------------------------------------------------------------------------
# @115820 We'd like to take a further look into this with you! Please reach us by phone or chat here: https://t.co/hApLpMlfHN ^AG
# ----------------------------------------------------------------------------------------------------
# @AmazonHelp I frankly don't have the patience for another chat with your "customer service" people today.
# ----------------------------------------------------------------------------------------------------
# @115823 I want my amazon payments account CLOSED.  dm me please.
# ----------------------------------------------------------------------------------------------------
# @115822 I am unable to affect your account via Twitter. For real time support, phone or chat use this link: https://t.co/hApLpMlfHN ^CH
# ----------------------------------------------------------------------------------------------------
# @115825 also, beim Addams Family-Film in Prime sind Bild und Ton nicht wirklich synchron. Wie kommt's?
# ----------------------------------------------------------------------------------------------------
# @115824 Hi, wir erhalten die Filme/Serien so vom jeweiligen Studio. Gebe ich aber direkt als Feedback dorthin weiter. Gruß ^JS
# ----------------------------------------------------------------------------------------------------
# @AmazonHelp Okay, danke für die Info
# ----------------------------------------------------------------------------------------------------
# @115824 Wir haben zu danken. Schönen Abend noch. ^JS
# ----------------------------------------------------------------------------------------------------
# @115828 How about you guys figure out my Xbox One X project Scorpio edition first. No expected delivery or shipping date and it’s only a week away
# ----------------------------------------------------------------------------------------------------
# @115826 I'm sorry for the wait. You'll receive an email as soon as we have an estimated delivery date. ^FJ
# ----------------------------------------------------------------------------------------------------

# %%
company_mentions = (
    amazon_sorted["text"]
    .str.findall(r"@\w+")
    .explode()
    .value_counts()
)

print(company_mentions.head(30))
# Out:
# text
# @AmazonHelp    136680
# @115821         22640
# @115850         21663
# @115830          9232
# @115851          3405
# @120533          2531
# @116928          2097
# @116316          1683
# @116875          1593
# @117086          1509
# @119625          1332
# @117795           797
# @115833           791
# @115817           716
# @116618           714
# @118702           708
# @116090           683
# @118706           647
# @117634           646
# @118919           527
# @115825           469
# @amazonhelp       458
# @120540           420
# @119356           360
# @117093           349
# @UPSHelp          340
# @116313           339
# @116935           303
# @132994           286
# @137605           283
# Name: count, dtype: int64

# %%
import re

# %%
def clean_text(text):

    # 1. Remove URLs
    text = re.sub(r"https?://\S+", "", text)

    # 2. Replace @123456 with [USER]
    text = re.sub(r"@\d+", "[USER]", text)

    # 3. Replace newline characters with spaces
    text = re.sub(r"\s+", " ", text)

    # 4. Strip leading/trailing spaces
    text = text.strip()

    # 5. Return cleaned text
    return text

# %%
test_texts = [
    "@115770 I have an order problem https://t.co/example",
    "@AmazonHelp My order hasn't arrived 😭",
    "@UPSHelp Please check my package",
    "Hello\n\nI need help with my refund",
    "   My order     is delayed   "
]

for text in test_texts:
    print("BEFORE:", text)
    print("AFTER :", clean_text(text))
    print("-" * 80)
# Out:
# BEFORE: @115770 I have an order problem https://t.co/example
# AFTER : [USER] I have an order problem
# --------------------------------------------------------------------------------
# BEFORE: @AmazonHelp My order hasn't arrived 😭
# AFTER : @AmazonHelp My order hasn't arrived 😭
# --------------------------------------------------------------------------------
# BEFORE: @UPSHelp Please check my package
# AFTER : @UPSHelp Please check my package
# --------------------------------------------------------------------------------
# BEFORE: Hello
#
# I need help with my refund
# AFTER : Hello I need help with my refund
# --------------------------------------------------------------------------------
# BEFORE:    My order     is delayed
# AFTER : My order is delayed
# --------------------------------------------------------------------------------

# %%
amazon_sorted["clean_text"] = amazon_sorted["text"].apply(clean_text)

amazon_sorted[["text", "clean_text"]].head(20)
# Out:
#                                                   text  \
# 187                           amazonのfireTVstickが見れない😢
# 181  @115770 こんにちは、アマゾン公式です。Fire TV Stickが見れないというのは...
# 182      @AmazonHelp ありがとうございます。\n今、電話で主人が対応していただいてます。
# 183  @AmazonHelp 電話で対応してもらいましたが改良されませんでした。\n保証期間も過ぎ...
# 184  @115770 カスタマーサービスにてお問い合わせ済みとのことで、お手数をおかけいたしました...
# 185                      @AmazonHelp こちらこそありがとうございました。
# 186  @115770 恐れ入ります。至らない点も多々あるかとは存じますが、今後ともどうぞよろしくお...
# 235                           amazonプライムビデオ、再生エラーが多いです
# 234  @115792 ご不便をおかけしております。アプリをご利用でしょうか。強制停止&gt;端末の...
# 325  Way to drop the ball on customer service @1158...
# 321  @115820 I'm sorry we've let you down! Without ...
# 322  @AmazonHelp 3 different people have given 3 di...
# 323  @115820 We'd like to take a further look into ...
# 324  @AmazonHelp I frankly don't have the patience ...
# 327  @115823 I want my amazon payments account CLOS...
# 326  @115822 I am unable to affect your account via...
# 331  @115825 also, beim Addams Family-Film in Prime...
# 328  @115824 Hi, wir erhalten die Filme/Serien so v...
# 329               @AmazonHelp Okay, danke für die Info
# 330  @115824 Wir haben zu danken. Schönen Abend noc...
#
#                                             clean_text
# 187                           amazonのfireTVstickが見れない😢
# 181  [USER] こんにちは、アマゾン公式です。Fire TV Stickが見れないというのは、...
# 182       @AmazonHelp ありがとうございます。 今、電話で主人が対応していただいてます。
# 183  @AmazonHelp 電話で対応してもらいましたが改良されませんでした。 保証期間も過ぎて...
# 184  [USER] カスタマーサービスにてお問い合わせ済みとのことで、お手数をおかけいたしました。...
# 185                      @AmazonHelp こちらこそありがとうございました。
# 186  [USER] 恐れ入ります。至らない点も多々あるかとは存じますが、今後ともどうぞよろしくお願...
# 235                           amazonプライムビデオ、再生エラーが多いです
# 234  [USER] ご不便をおかけしております。アプリをご利用でしょうか。強制停止&gt;端末の再...
# 325  Way to drop the ball on customer service [USER...
# 321  [USER] I'm sorry we've let you down! Without p...
# 322  @AmazonHelp 3 different people have given 3 di...
# 323  [USER] We'd like to take a further look into t...
# 324  @AmazonHelp I frankly don't have the patience ...
# 327  [USER] I want my amazon payments account CLOSE...
# 326  [USER] I am unable to affect your account via ...
# 331  [USER] also, beim Addams Family-Film in Prime ...
# 328  [USER] Hi, wir erhalten die Filme/Serien so vo...
# 329               @AmazonHelp Okay, danke für die Info
# 330  [USER] Wir haben zu danken. Schönen Abend noch...

# %%
remaining_urls = amazon_sorted["clean_text"].str.contains(
    r"http|https|t\.co",
    case=False,
    regex=True,
    na=False
).sum()

print("URLs remaining:", remaining_urls)

remaining_user_mentions = amazon_sorted["clean_text"].str.contains(
    r"@\d+",
    regex=True,
    na=False
).sum()

print("Numeric mentions remaining:", remaining_user_mentions)

remaining_newlines = amazon_sorted["clean_text"].str.contains(
    r"\n",
    regex=True,
    na=False
).sum()

print("Newlines remaining:", remaining_newlines)

empty_clean_text = (
    amazon_sorted["clean_text"]
    .str.strip()
    .eq("")
    .sum()
)

print("Empty cleaned tweets:", empty_clean_text)

sample = amazon_sorted[
    amazon_sorted["text"] != amazon_sorted["clean_text"]
].sample(
    10,
    random_state=42
)

for _, row in sample.iterrows():
    print("ORIGINAL:")
    print(row["text"])
    
    print("\nCLEANED:")
    print(row["clean_text"])
    
    print("\n" + "=" * 100 + "\n")
# Out:
# URLs remaining: 149
# Numeric mentions remaining: 0
# Newlines remaining: 0
# Empty cleaned tweets: 15
# ORIGINAL:
# @115821 Order# 112-2959570-0614617  Please investigate your customer service work and reply to your customer! Be aware of dishonest seller!
#
# CLEANED:
# [USER] Order# 112-2959570-0614617 Please investigate your customer service work and reply to your customer! Be aware of dishonest seller!
#
# ====================================================================================================
#
# ORIGINAL:
# @AmazonHelp Who's security?  UR asking 4 MY personal details.  Surely U have company phone #s that aren't "personal."  This is absurd. I'm TRYING 2 work w/U people. Y do U make it so hard?  May I be referred to a mgr who isn't afraid 2 speak w/an intelligent, reasonable woman 2 work out sols
#
# CLEANED:
# @AmazonHelp Who's security? UR asking 4 MY personal details. Surely U have company phone #s that aren't "personal." This is absurd. I'm TRYING 2 work w/U people. Y do U make it so hard? May I be referred to a mgr who isn't afraid 2 speak w/an intelligent, reasonable woman 2 work out sols
#
# ====================================================================================================
#
# ORIGINAL:
# Amazon India did it again! I wasn't really surprised when I received a SAMHE J5 instead of OnePlus 5T. This... https://t.co/LRSGi9zvWt
#
# CLEANED:
# Amazon India did it again! I wasn't really surprised when I received a SAMHE J5 instead of OnePlus 5T. This...
#
# ====================================================================================================
#
# ORIGINAL:
# Does @115821 work delivering to #Morocco ... ideally ASAP (next day  even?)
#
# CLEANED:
# Does [USER] work delivering to #Morocco ... ideally ASAP (next day even?)
#
# ====================================================================================================
#
# ORIGINAL:
# @115850 What the hell is wrong with you. Learn a thing or two from your competitor @118702. you hardly ever need to call their customer support and if you do they resolve your query. On the other hand your delivery suck big time even for prime member. Up your game or gtfo.
#
# CLEANED:
# [USER] What the hell is wrong with you. Learn a thing or two from your competitor [USER]. you hardly ever need to call their customer support and if you do they resolve your query. On the other hand your delivery suck big time even for prime member. Up your game or gtfo.
#
# ====================================================================================================
#
# ORIGINAL:
# @116090 what happens when you order says delivered at 11:21 am, but you for sure didn’t get any delivery and someone’s been home all day?
#
# CLEANED:
# [USER] what happens when you order says delivered at 11:21 am, but you for sure didn’t get any delivery and someone’s been home all day?
#
# ====================================================================================================
#
# ORIGINAL:
# @164808 I request you to reply to our email with your concern so that we can assist you accordingly. ^VH
#
# CLEANED:
# [USER] I request you to reply to our email with your concern so that we can assist you accordingly. ^VH
#
# ====================================================================================================
#
# ORIGINAL:
# @242975 Hi Amazon  my package is over due, give it to that guy, had my $$ same day I ordered, two months ago assholes @115821
#
# CLEANED:
# [USER] Hi Amazon my package is over due, give it to that guy, had my $$ same day I ordered, two months ago assholes [USER]
#
# ====================================================================================================
#
# ORIGINAL:
# @115850 - I have received a message that my Amazon product has been delivered. Dude I am waiting for the product and nobody came to myhome https://t.co/vkSzLRB4cV
#
# CLEANED:
# [USER] - I have received a message that my Amazon product has been delivered. Dude I am waiting for the product and nobody came to myhome
#
# ====================================================================================================
#
# ORIGINAL:
# @232320 We've responded to your Direct Message! Let us know what we can do to help! ^MT
#
# CLEANED:
# [USER] We've responded to your Direct Message! Let us know what we can do to help! ^MT
#
# ====================================================================================================

# %%
remaining_urls = amazon_sorted["clean_text"].str.contains(
    r"https?://\S+",
    regex=True,
    na=False
).sum()

print("Actual URLs remaining:", remaining_urls)
# Out:
# Actual URLs remaining: 0

# %%
empty_examples = amazon_sorted[
    amazon_sorted["clean_text"].str.strip() == ""
]

print(
    empty_examples[
        [
            "conversation_id",
            "tweet_id",
            "author_id",
            "inbound",
            "text",
            "clean_text"
        ]
    ].to_string(index=False)
)
# Out:
#  conversation_id  tweet_id author_id  inbound                                            text clean_text
#            96704     96703    137102     True                         https://t.co/MaiDMbahcK
#           144191    144191    115821     True                         https://t.co/TJv7fBjqGJ
#           279175    279175    182576     True                         https://t.co/MRgqJVCl3x
#           722492    722491    292983     True                         https://t.co/8u9ZmNinDF
#           969291    969291    218503     True                         https://t.co/NyAuiFpvBr
#          1108277   1108276    381559     True                         https://t.co/fFFYfgBHyn
#          1193911   1193911    400536     True                         https://t.co/6AB5B9jL1D
#          1561133   1561133    482291     True                         https://t.co/x1dE72Eo4o
#          1771864   1771864    303368     True https://t.co/wbQnZ9148U https://t.co/lOabmQ0X6R
#          2288560   2288560    656689     True                         https://t.co/aTe8SE0NrG
#          2599055   2599055    735811     True                         https://t.co/7Fdmd2CIR4
#          2756768   2756768    771541     True                         https://t.co/xp5fThBb5W
#          2866129   2866127    796057     True                         https://t.co/CyDmh2LH9U
#          2905040   2905040    461507     True                         https://t.co/oQUUhYfvod
#          2913224   2913222    806459     True                         https://t.co/pE8igqD6Y9

# %%
amazon_clean = amazon_sorted[
    amazon_sorted["clean_text"].str.strip() != ""
].copy()

# %%
print("Conversations before:", amazon_sorted["conversation_id"].nunique())
print("Conversations after:", amazon_clean["conversation_id"].nunique())
# Out:
# Conversations before: 82534
# Conversations after: 82534

# %%
amazon_clean.to_csv(
    "../data/processed/amazonhelp_cleaned.csv",
    index=False
)
